# %% [markdown]
# # Librerías

# %%
import yaml
import numpy as np
import sympy as sp
import Newt_Raph as nr

# %% [markdown]
# # Def. Polinomio de Legendre

# %%
def Legendre(n):
    x = sp.Symbol("x",Real=True)
    y = sp.Symbol("y",Real=True)
    
    poly = ((np.e**x)/np.math.factorial(n))*sp.diff(((((x**2)-1)**n)),x,n)
    poly=sp.lambdify([x],poly,'numpy')
    return poly

# %% [markdown]
# # Raíces hasta el vigésimo polinomio

# %%
def roots_20p():
    roots={}
    
    for i in range(1,21):
        x = np.linspace(-1,1,100)
        r = nr.GetAllRoots(x,Legendre(i))
            
        roots["Polinomio "+str(i)] = r.tolist()
        
    return roots

# %% [markdown]
# # Presentación de las raíces

# %%
roots=roots_20p()
print(yaml.dump(roots, sort_keys=False, default_flow_style=False))
# Out:
# c:\Users\Usuario\Desktop\U\Métodos I\Metodos1_SergioLopez_SergioMontoya\Taller 3\Newt_Raph.py:24: RuntimeWarning: divide by zero encountered in double_scalars
#   xn1 = xn - f(xn)/df(f,xn)
# c:\Users\Usuario\Desktop\U\Métodos I\Metodos1_SergioLopez_SergioMontoya\Taller 3\Newt_Raph.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   return (f(x+h)-f(x-h))/(2*h)
# c:\Users\Usuario\Desktop\U\Métodos I\Metodos1_SergioLopez_SergioMontoya\Taller 3\Newt_Raph.py:25: RuntimeWarning: invalid value encountered in double_scalars
#   error=np.abs((xn1-xn)/xn)
# Polinomio 1:
# - 0.0
# - .nan
# Polinomio 2:
# - -2.0
# - -0.57735
# - 0.57735
# Polinomio 3:
# - -0.774597
# - -0.0
# - 0.774597
# Polinomio 4:
# - -0.861136
# - -0.339981
# - 0.339981
# - 0.861136
# Polinomio 5:
# - -0.90618
# - -0.538469
# - 0.0
# - 0.538469
# - 0.90618
# Polinomio 6:
# - -20.0
# - -0.93247
# - -0.661209
# - -0.238619
# - 0.238619
# - 0.661209
# - 0.93247
# Polinomio 7:
# - -0.949108
# - -0.741531
# - -0.405845
# - -0.0
# - 0.405845
# - 0.741531
# - 0.949108
# Polinomio 8:
# - -0.96029
# - -0.796666
# - -0.525532
# - -0.183435
# - 0.183435
# - 0.525532
# - 0.796666
# - 0.96029
# Polinomio 9:
# - -0.96816
# - -0.836031
# - -0.613371
# - -0.324253
# - 0.0
# - 0.324253
# - 0.613371
# - 0.836031
# - 0.96816
# Polinomio 10:
# - -252.0
# - -0.973907
# - -0.865063
# - -0.67941
# - -0.433395
# - -0.148874
# - 0.148874
# - 0.433395
# - 0.67941
# - 0.865063
# - 0.973907
# Polinomio 11:
# - -0.978229
# - -0.887063
# - -0.730152
# - -0.519096
# - -0.269543
# - -0.0
# - 0.269543
# - 0.519096
# - 0.730152
# - 0.887063
# - 0.978229
# Polinomio 12:
# - -0.981561
# - -0.904117
# - -0.769903
# - -0.587318
# - -0.367831
# - -0.125233
# - 0.125233
# - 0.367831
# - 0.587318
# - 0.769903
# - 0.904117
# - 0.981561
# Polinomio 13:
# - -0.984183
# - -0.917598
# - -0.801578
# - -0.642349
# - -0.448493
# - -0.230458
# - 0.0
# - 0.230458
# - 0.448493
# - 0.642349
# - 0.801578
# - 0.917598
# - 0.984183
# Polinomio 14:
# - -3432.0
# - -0.986284
# - -0.928435
# - -0.827201
# - -0.687293
# - -0.515249
# - -0.319112
# - -0.108055
# - 0.108055
# - 0.319112
# - 0.515249
# - 0.687293
# - 0.827201
# - 0.928435
# - 0.986284
# Polinomio 15:
# - -0.987993
# - -0.937273
# - -0.848207
# - -0.724418
# - -0.570972
# - -0.394151
# - -0.201194
# - -0.0
# - 0.201194
# - 0.394151
# - 0.570972
# - 0.724418
# - 0.848207
# - 0.937273
# - 0.987993
# Polinomio 16:
# - -0.989401
# - -0.944575
# - -0.865631
# - -0.755404
# - -0.617876
# - -0.458017
# - -0.281604
# - -0.095013
# - 0.095013
# - 0.281604
# - 0.458017
# - 0.617876
# - 0.755404
# - 0.865631
# - 0.944575
# - 0.989401
# Polinomio 17:
# - -0.990575
# - -0.950676
# - -0.880239
# - -0.781514
# - -0.657671
# - -0.512691
# - -0.351232
# - -0.178484
# - 0.0
# - 0.178484
# - 0.351232
# - 0.512691
# - 0.657671
# - 0.781514
# - 0.880239
# - 0.950676
# - 0.990575
# Polinomio 18:
# - -48620.0
# - -0.991565
# - -0.955824
# - -0.892602
# - -0.803705
# - -0.691687
# - -0.559771
# - -0.411751
# - -0.251886
# - -0.084775
# - 0.084775
# - 0.251886
# - 0.411751
# - 0.559771
# - 0.691687
# - 0.803705
# - 0.892602
# - 0.955824
# - 0.991565
# Polinomio 19:
# - -0.992407
# - -0.960208
# - -0.903156
# - -0.822715
# - -0.720966
# - -0.600545
# - -0.464571
# - -0.316564
# - -0.160359
# - -0.0
# - 0.160359
# - 0.316564
# - 0.464571
# - 0.600545
# - 0.720966
# - 0.822715
# - 0.903156
# - 0.960208
# - 0.992407
# Polinomio 20:
# - -0.993129
# - -0.963972
# - -0.912234
# - -0.839117
# - -0.746332
# - -0.636054
# - -0.510867
# - -0.373706
# - -0.227786
# - -0.076527
# - 0.076527
# - 0.227786
# - 0.373706
# - 0.510867
# - 0.636054
# - 0.746332
# - 0.839117
# - 0.912234
# - 0.963972
# - 0.993129
