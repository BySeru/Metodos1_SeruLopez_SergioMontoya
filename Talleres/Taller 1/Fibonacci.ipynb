# %% [markdown]
# # Librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Vigésimo término de Fibonacci

# %%
def fibonacci(term=20):
    a=0
    b=1
    list=[]
    
    for i in range(term):
        list.append(a)
        f_sum =a+b
        a=b
        b=f_sum
    
    return list

# %% [markdown]
# # Razón áurea

# %%
def aurea(list=fibonacci()):
    phi=(1+(5)**(1/2))/2
    phi_lim=[]
    phi_list=[]
    n_1=1

    for n_2 in range(1,len(list)):
        phi_f=list[n_2]/list[n_1]
        phi_lim.append(phi_f)
        phi_list.append(phi)
        n_1=n_2
    
    return phi_lim,phi_list

# %% [markdown]
# # Gráficas

# %%
# ==============================
# Sucesión
# ==============================
coor_y=fibonacci()
coor_x=np.arange(1,(len(coor_y)+1))
fig,ax=plt.subplots()
ax.plot(coor_x,coor_y, label="Vigésimo término")
ax.set_title('Sucesión de Fibonacci')
leg = ax.legend()
plt.show()

# ==============================
# Razón áurea
# ==============================
coor_y,phi=aurea(coor_y)
coor_x=np.arange(1,(len(coor_y)+1))
fig,ax=plt.subplots()
ax.plot(coor_x,coor_y, label="phi calculado")
ax.plot(coor_x,phi, "--r", label='phi')
ax.set_title('Razón áurea')
leg = ax.legend()
plt.show()
