# %% [markdown]
# # Librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráfica

# %%
r = np.linspace(0, 2*np.pi*3)

x = r*np.cos(r)
y = r*np.sin(r)

plt.figure(figsize=(8,5))
plt.plot(x,y)
plt.title("Espiral de Arquimedes")
plt.xlabel("$\it{x}$")
plt.ylabel("$\it{y}$")
plt.show()
